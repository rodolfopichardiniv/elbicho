# %% [markdown]
# **Bernardo Camarena y Rodolfo Pichardini**

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/ds_salaries.csv")
data
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
data.tail()
# Out:
#      Unnamed: 0  work_year experience_level employment_type      job_title  \
# 602         602       2022               SE              FT  Data Engineer
# 603         603       2022               SE              FT  Data Engineer
# 604         604       2022               SE              FT   Data Analyst
# 605         605       2022               SE              FT   Data Analyst
# 606         606       2022               MI              FT   AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
data.shape
# Out:
# (607, 12)

# %%
data.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
data["salary_in_usd"]
# Out:
# 0       79833
# 1      260000
# 2      109024
# 3       20000
# 4      150000
#         ...
# 602    154000
# 603    126000
# 604    129000
# 605    150000
# 606    200000
# Name: salary_in_usd, Length: 607, dtype: int64

# %%
type(data["salary_in_usd"])
# Out:
# pandas.core.series.Series

# %%
data[["job_title","salary_in_usd"]]
# Out:
#                       job_title  salary_in_usd
# 0                Data Scientist          79833
# 1    Machine Learning Scientist         260000
# 2             Big Data Engineer         109024
# 3          Product Data Analyst          20000
# 4     Machine Learning Engineer         150000
# ..                          ...            ...
# 602               Data Engineer         154000
# 603               Data Engineer         126000
# 604                Data Analyst         129000
# 605                Data Analyst         150000
# 606                AI Scientist         200000
#
# [607 rows x 2 columns]

# %%
data.loc[2]
# Out:
# Unnamed: 0                            2
# work_year                          2020
# experience_level                     SE
# employment_type                      FT
# job_title             Big Data Engineer
# salary                            85000
# salary_currency                     GBP
# salary_in_usd                    109024
# employee_residence                   GB
# remote_ratio                         50
# company_location                     GB
# company_size                          M
# Name: 2, dtype: object

# %%
data.iloc[7:10][["job_title","salary_in_usd"]]
# Out:
#                job_title  salary_in_usd
# 7         Data Scientist          35735
# 8  Business Data Analyst         135000
# 9     Lead Data Engineer         125000

# %% [markdown]
# Trabajos que pagan mas de 1000 dolares y son en USA

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
dataUS = data[(data["salary_in_usd"]>=1000) & (data["employee_residence"] == "US")]
dataUS
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 4             4       2020               SE              FT
# 5             5       2020               EN              FT
# 6             6       2020               SE              FT
# 8             8       2020               MI              FT
# 13           13       2020               MI              FT
# ..          ...        ...              ...             ...
# 599         599       2022               MI              FT
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
#
#                      job_title  salary salary_currency  salary_in_usd  \
# 4    Machine Learning Engineer  150000             USD         150000
# 5                 Data Analyst   72000             USD          72000
# ...

# %% [markdown]
# Los 10 puestos de trabajo que por promedio mas ganan en USD

# %%
data.groupby("job_title")[["salary_in_usd"]].mean().sort_values(["salary_in_usd"], ascending = False).head(10)
# Out:
#                           salary_in_usd
# job_title
# Data Analytics Lead       405000.000000
# Principal Data Engineer   328333.333333
# Financial Data Analyst    275000.000000
# Principal Data Scientist  215242.428571
# Director of Data Science  195074.000000
# Data Architect            177873.909091
# Applied Data Scientist    175655.000000
# Analytics Engineer        175000.000000
# Data Specialist           165000.000000
# Head of Data              160162.600000

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# no hay datos nulos en la data

# %% [markdown]
# vamos a crear una columna con un indice que te clasifique en que continente esta el employee residence

# %%
data["employee_residence"].unique()
# Out:
# array(['DE', 'JP', 'GB', 'HN', 'US', 'HU', 'NZ', 'FR', 'IN', 'PK', 'PL',
#        'PT', 'CN', 'GR', 'AE', 'NL', 'MX', 'CA', 'AT', 'NG', 'PH', 'ES',
#        'DK', 'RU', 'IT', 'HR', 'BG', 'SG', 'BR', 'IQ', 'VN', 'BE', 'UA',
#        'MT', 'CL', 'RO', 'IR', 'CO', 'MD', 'KE', 'SI', 'HK', 'TR', 'RS',
#        'PR', 'LU', 'JE', 'CZ', 'AR', 'DZ', 'TN', 'MY', 'EE', 'AU', 'BO',
#        'IE', 'CH'], dtype=object)

# %% [markdown]
# sacamos los valores unique de la columna de paises, por temas de complejidad, no sabemos que paises son, por ejemplo DE, NL, etc. Entonces agruparemos paises en los continentes, pero solo ser[a un ejemplo demostrativo, nada 100% atinado por que no sabemos cuales son los paises.

# %%
def continente(residence):
  if residence == "DE" or "US" or "MX":
    return "America"
  elif residence == 'NZ'or 'FR'or 'IN'or 'PK'or 'PL'or'PT'or 'CN'or'GR'or'AE'or 'NL'or 'SI'or 'HK'or 'TR'or 'RS'or'PR':
    return "Europa"
  elif residence == 'CA'or 'AT'or 'NG'or 'PH'or 'ES'or'DK'or 'RU'or 'IT'or 'HR'or 'BG'or 'SG'  or 'JP' or 'GB' or 'HN'or 'HU' or 'CZ'or 'AR'or 'DZ':
    return "Africa"
  elif residence == 'BR'or 'IQ'or 'VN'or 'BE'or 'UA'or'MT'or 'CL'or 'RO'or 'IR'or 'CO'or 'MD'or 'KE'or 'LU'or 'JE'or 'TN'or 'MY'or 'EE':
    return "Asia"
  elif residence == 'AU'or 'BO'or'IE'or 'CH':
    return "Oceania"

# %%
data['company_location'].apply(lambda x: str(x))
# Out:
# 0      DE
# 1      JP
# 2      GB
# 3      HN
# 4      US
#        ..
# 602    US
# 603    US
# 604    US
# 605    US
# 606    US
# Name: company_location, Length: 607, dtype: object

# %%
data["continentes"] = data["company_location"].apply(continente)
data.continentes.values
# Out:
# array(['America', 'America', 'America', 'America', 'America', 'America',
#        'America', 'America', 'America', 'America', 'America', 'America',
#        'America', 'America', 'America', 'America', 'America', 'America',
#        'America', 'America', 'America', 'America', 'America', 'America',
#        'America', 'America', 'America', 'America', 'America', 'America',
#        'America', 'America', 'America', 'America', 'America', 'America',
#        'America', 'America', 'America', 'America', 'America', 'America',
#        'America', 'America', 'America', 'America', 'America', 'America',
#        'America', 'America', 'America', 'America', 'America', 'America',
#        'America', 'America', 'America', 'America', 'America', 'America',
#        'America', 'America', 'America', 'America', 'America', 'America',
#        'America', 'America', 'America', 'America', 'America', 'America',
#        'America', 'America', 'America', 'America', 'America', 'America',
# ...

# %% [markdown]
# ahora una columna que nos convierta los salarios de dolares a pesos

# %%
def salariospesos(salario):
  return salario*20.04

# %%
data["salario_en_pesosMX"] = data["salary_in_usd"].apply(salariospesos)

# %%
data
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({"font.size":20, "figure.figsize": (12,9)} )

# %%
data.plot(kind = "scatter", x = "job_title", y = "salary_in_usd", title = "Trabajos vs Salario USD")

# %%
data["salary_in_usd"].plot(kind = "hist", title = "salario en usd")

# %%
data["salary_in_usd"].plot(kind = "box")

# %%
data.boxplot(column = "salary_in_usd", by = "job_title")
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
